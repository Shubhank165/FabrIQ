# %%
print("Start 4")

# %%
# !pip install dominate

# %%
# !git clone https://github.com/shadow2496/VITON-HD.git /kaggle/working/VITON-HD

# %%
# !mkdir -p /kaggle/working/VITON-HD/data
# !cp -r /kaggle/input/high-resolution-viton-zalando-dataset/test /kaggle/working/VITON-HD/data/

# %%
# !mkdir -p /kaggle/working/VITON-HD/checkpoints/default/1
# !cp /kaggle/input/viton-hd-models/pytorch/default/1/*.pth /kaggle/working/VITON-HD/checkpoints/default/1/

# %%
# !pip install -q yacs opencv-python numpy pillow matplotlib
# !pip install torchgeometry

# %%
file_path = '/kaggle/working/VITON-HD/datasets.py'

# Read the file content
with open(file_path, 'r') as file:
    lines = file.readlines()

# Replace 'openpose-img' with 'openpose_img'
new_lines = [line.replace('image-parse', 'image-parse-v3') for line in lines]
print(len(new_lines))
# Write back the modified content
with open(file_path, 'w') as file:
    file.writelines(new_lines)

print("✅ Successfully replaced 'openpose-img' with 'openpose_img' in datasets.py")

# %%
file_path = '/kaggle/working/VITON-HD/datasets.py'

# Read the file content
with open(file_path, 'r') as file:
    lines = file.readlines()

# Replace 'openpose-img' with 'openpose_img'
new_lines = [line.replace('openpose-img', 'openpose_img') for line in lines]
print(len(new_lines))
# Write back the modified content
with open(file_path, 'w') as file:
    file.writelines(new_lines)

print("✅ Successfully replaced 'openpose-img' with 'openpose_img' in datasets.py")

# %%
file_path = '/kaggle/working/VITON-HD/datasets.py'

# Read the file content
with open(file_path, 'r') as file:
    lines = file.readlines()

# Replace 'openpose-img' with 'openpose_img'
new_lines = [line.replace('openpose-json', 'openpose_json') for line in lines]
print(len(new_lines))
# Write back the modified content
with open(file_path, 'w') as file:
    file.writelines(new_lines)

print("✅ Successfully replaced 'openpose-img' with 'openpose_img' in datasets.py")

# %%
cloth_img = "00017_00.jpg"
person_img = "00013_00.jpg"
with open("/kaggle/working/VITON-HD/data/test_pairs_single.txt", "w") as f:
    f.write(f"{person_img} {cloth_img}\n")

# %%
# !python /kaggle/working/VITON-HD/test.py \
  --name "default" \
  --dataset_dir "/kaggle/input/high-resolution-viton-zalando-dataset" \
  --dataset_list "/kaggle/working/VITON-HD/data/test_pairs_single.txt" \
  --checkpoint_dir "/kaggle/working/VITON-HD/checkpoints/default" \
  --seg_checkpoint "1/seg_final.pth" \
  --gmm_checkpoint "1/gmm_final.pth" \
  --alias_checkpoint "1/alias_final.pth" \
  --save_dir "/kaggle/working/VITON-HD/results/v5"

# %%
import shutil

# Copy the file to the /kaggle/working directory (downloadable area)
shutil.copy('/kaggle/input/high-resolution-viton-zalando-dataset/test/image/00013_00.jpg', '/kaggle/working/inp.jpg')
